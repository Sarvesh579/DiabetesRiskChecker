# %%
import pandas as pd
import joblib

# %%
# Load model
model = joblib.load('diabetes_prediction_model_bren.pkl')
# Out:
# C:\Users\Sarvesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:440: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Define the input with correct column names
input = pd.DataFrame([40, 1, 1, 1, 1, 0, 0, 1, 0, 0, 0, 0, 0])

# %%
# Define the input with correct column names
input_df = pd.DataFrame([{
    "Age": 40,
    "Sex": 0,
    "Polyuria": 0,
    "Polydipsia": 0,
    "sudden_weight_loss": 0,
    "weakness": 0,
    "Polyphagia": 0,
    "Genital_thrush": 0,
    "visual_blurring": 0,
    "Itching": 0,
    "Irritability": 0,
    "delayed_healing": 0,
    "partial_paresis": 0,
    "muscle_stiffness": 0,
    "Alopecia": 0,
    "Obesity": 0
}])

# %%
# Predict
prediction = model.predict_proba(input)
pred = prediction[0][1]
print(f"Predicted probability of diabetes: {pred}\n")
# Out:
# C:\Users\Sarvesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 2
#       1 # Predict
# ----> 2 prediction = model.predict_proba(input)
#       3 pred = prediction[0][1]
#       4 print(f"Predicted probability of diabetes: {pred}\n")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:1454, in LogisticRegression.predict_proba(self, X)
#    1449 ovr = self.multi_class in ["ovr", "warn"] or (
#    1450     self.multi_class in ["auto", "deprecated"]
# ...
